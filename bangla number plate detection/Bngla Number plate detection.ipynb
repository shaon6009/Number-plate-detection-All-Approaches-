# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="RdJ2NtyX9m5xAyE0VGdO")
project = rf.workspace("shaon-xpd2i").project("vehicle-license-plate-text-recognition-omayf")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vehicle-License-Plate-Text-Recognition-1 in yolov11:: 100%|██████████| 5328/5328 [00:02<00:00, 2096.36it/s]

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/yolo11m.pt')

train_result = model.train(
    data="/content/Vehicle-License-Plate-Text-Recognition-1/data.yaml",
    epochs=50,
    imgsz=640,
    device='0'
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.57 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model("/content/Vehicle-License-Plate-Text-Recognition-1/valid/images/1001_jpg.rf.b731dc3282dab8f37ff8f6b4371a3083.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/Vehicle-License-Plate-Text-Recognition-1/valid/images/1001_jpg.rf.b731dc3282dab8f37ff8f6b4371a3083.jpg: 448x640 2 1s, 2 2s, 1 5, 1 6, 1 Gopalganj, 1 Ha, 49.7ms
# Speed: 2.1ms preprocess, 49.7ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3
# <PIL.Image.Image image mode=RGB size=866x569>

# %% [markdown]
# # for Video

# %%
# Perform object detection on an image
model = YOLO("/content/runs/detect/train3/weights/best.pt")
results = model("test_videos/1.mp4", save=True)
